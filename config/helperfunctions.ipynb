# %%
import sys
import os
import urllib
import json
import re
import pandas as pd
import numpy as np
import seaborn as sns
import itertools

# %%
#Open schedule between start and end date (format YYYY-MM-DD)
def scheduleOpener(start, end):
    """Date format: 'YYYY-MM-DD'
    
    Returns a dataframe containing information for every game within
    the dates provided.
    """
    #Confirm start/end is in string format
    start = str(start)
    end = str(end)
    
    #Access the API endpoint for the schedule
    schedule = urllib.request.urlopen('https://statsapi.web.nhl.com/api/v1/schedule?startDate=%s&endDate=%s' % (start, end))
    
    #Load the data in with json.loads
    scheduledata = json.loads(schedule.read().decode(schedule.info().get_param('charset') or 'utf-8'))
    
    season = pd.io.json.json_normalize(scheduledata, record_path = ['dates', 'games'])
    
    #Subset the data for only regular and playoff games
    season = season[(season['gameType'] == 'R') | (season['gameType'] == 'P')]
    
    #Clean up the index after the subsetting
    season.reset_index(drop=True, inplace=True)
    
    return season


#Load all the plays within the provided game link
def loadGamePlays(gamelink):
    """This takes links from cleanSeasonDf['link'].
    Open up a link to a game to get every play that occurred. Returns a tuple
    with (plays - df, homeTeam - triCode for home team, awayTeam - triCode for away team)"""
    
    #Open a game link
    game = urllib.request.urlopen(base+gamelink)
    gamedata = json.loads(game.read().decode(game.info().get_param('charset') or 'utf-8'))

    #Grab the data about every play that happened
    plays = gamedata['liveData']['plays']['allPlays']
    
    #Also grab the tricodes for the involved teams for future use
    homeTeam = gamedata['gameData']['teams']['home']['triCode']
    awayTeam = gamedata['gameData']['teams']['away']['triCode']
    
    return (plays, homeTeam, awayTeam)

def winningTeamPenalty(r):
    """Small helper function for gamePenaltyDf. Creates a new column which indicates if the 
    team who was winning at the time of a penalty is the one who took it"""
    
    #Check if home or away had more goals at the 'event' time
    homecheck = int(r['about.goals.home'] > r['about.goals.away'])
    awaycheck = int(r['about.goals.away'] > r['about.goals.home'])
    
    #If home had more goals and the penalty was on the home team, set to 1
    if (homecheck > 0) and (r['against.homeTeam'] == 1):
        return 1
    #If away had more and the penalty was not on home team, set to 1
    if (awaycheck > 0) and (r['against.homeTeam'] == 0):
        return 1
    #Any other situation should be a zero in this column
    else:
        return 0

def gamePenaltyDf(plays_home_away):
    """This takes output from loadGamePlays.
    Creates a df from all the plays in a game, then cleans up to only look at penalties. The resulting
    penalties df is then reduced only relevant columns, and the results are
    returned along with newly calculated columns.
    
    If there are no penalties to find we return 0"""
    
    #Load the read plays data into a dataframe
    playsdf = pd.io.json.json_normalize(plays_home_away[0])
    #Also grab the tricodes
    home_tricode = plays_home_away[1]
    away_tricode = plays_home_away[2]
    
    #Define the columns I want from the data
    relevant_columns = ['about.dateTime', 'about.eventId', 'about.goals.away', 'about.goals.home', 'about.period', 'about.periodTimeRemaining', 'result.penaltyMinutes', 'result.penaltySeverity', 'result.secondaryType', 'team.triCode']
    #Confirm that there are actually penalty minutes in the game
    if 'result.penaltyMinutes' in list(playsdf.columns):
        #Subset down to only plays which resulted in non-nan penalty minutes
        pdf = playsdf[playsdf['result.penaltyMinutes'].isna()==False]
        pdf.reset_index(drop=True, inplace=True)
        #Reduce the columns down to the relevant ones
        relevantdf = pdf[relevant_columns].copy()
        #Some manufactured columns
        relevantdf['against.homeTeam'] = relevantdf['team.triCode'].apply(lambda code: int(code == home_tricode))
        relevantdf['against.awayTeam'] = relevantdf['team.triCode'].apply(lambda code: int(code == away_tricode))
        relevantdf['committed.playingAgainst'] = relevantdf['team.triCode'].apply(lambda code: away_tricode if code == home_tricode else home_tricode)
        relevantdf['winning.teamPenalty'] = relevantdf.apply(lambda x: winningTeamPenalty(x), 1)
        #Markov Chain type columns - recording the state of the game and most recent state
        relevantdf['prev.against.home'] = relevantdf['against.homeTeam'].shift(1).fillna(0)
        relevantdf['prev.against.away'] = relevantdf['against.awayTeam'].shift(1).fillna(0)
        relevantdf['goal.diff'] = relevantdf['about.goals.home'] - relevantdf['about.goals.away']
        relevantdf['penalty.diff'] = relevantdf['against.homeTeam'].cumsum() - relevantdf['against.awayTeam'].cumsum()
        
        return relevantdf
    else:
        return 0
    
def updatePenaltyDf(temp_df, season, end):
    """Take in an existing df and updates it. Uses loadGamePlays, gamePenaltyDf and then appends
    the results to the provided df. End defines the game in the season at which
    to end the update. Season should be a cleanSeasonDf which has a column of 'links'."""
    
    #If the temp_df is empty, we start at game 0
    if np.nan_to_num(temp_df['gameNumber'].max()) == 0:
        start = 0
    else:
        #If it's not empty we start at the last game entered
        start = temp_df['gameNumber'].max()
        #Also confirm that we know what the last timestamp was to prevent duplication
        last_timestamp = temp_df.iloc[-1]['about.dateTime']

    for n in range(start, end):
        #Load the plays from games between start and the given end value
        plays_home_away = loadGamePlays(base+season['link'][n])
        #The result is the penalty df 
        result = gamePenaltyDf(plays_home_away)
        
        #If we are updating from the beginning of a previous df, and we aren't on the first game
        #then we make sure the event is later than the last one defined. Prevent's duplication.
        if (n == start) and (n > 0):
            result = result[result['about.dateTime'] > last_timestamp]
        
        #If result gets a 0 (no penalties in the game)
        if type(result) == int:
            #Just continue
            continue
        else:
            #Create a column for which game number the results are from
            game_number = [n]*len(result)
            #Also provide what type of game it was (R/P)
            game_type = [season['gameType'][n]]*len(result)
            result['regular.playoffs'] = game_type
            result['gameNumber'] = game_number
            #Append the results from the game to the provided temporary dataframe
            temp_df = temp_df.append(result)
    
    #Reset the index at the end since we've appended several together
    temp_df.reset_index(drop=True, inplace=True)
    
    #Create a copy of the result and return it
    updated_df = temp_df.copy()
    return updated_df

# %%
def pensPerGameAgainst(team1, team2, df, include_playoffs=True, only_playoffs=False):
    
    #Convert triCodes to strings
    t1 = str(team1)
    t2 = str(team2)
    
    #Should playoffs be included
    if include_playoffs == False:
        df = df[df['regular.playoffs'] == 'R']
    if only_playoffs == True:
        df = df[df['regular.playoffs'] == 'P']
    
    #Group up based on who took the penalty and who it was against
    grouping = df[['team.triCode', 'committed.playingAgainst', 'gameNumber', 'result.secondaryType']].groupby(['team.triCode', 'committed.playingAgainst'])
    
    #Grab the subset matching the requested teams
    team_vs_team = grouping.get_group((t1, t2))
    
    #Get the value counts and unique game numbers
    pens_and_counts = team_vs_team['result.secondaryType'].value_counts()
    per_game_pens_and_counts = pens_and_counts/team_vs_team['gameNumber'].nunique()
    penalties = pens_and_counts.keys().tolist()
    counts = pens_and_counts.values
    per_game_counts = per_game_pens_and_counts.values
    
    #Get league wide per game values
    league = df['result.secondaryType'].value_counts()/df['gameNumber'].nunique()
    included_penalties = [i for i in league.items() if i[0] in penalties]
    league_dict = dict(included_penalties)
    #Subtract per game values for the paired up teams -> distance from league average
    for tup in per_game_pens_and_counts.items():
        league_dict[tup[0]] = tup[1] - league_dict[tup[0]] 
    
    #Create the plots
    fig, ax = plt.subplots(ncols=2, figsize=(12,6), sharey=False)

    pergame = sns.barplot(x=per_game_counts, y=penalties, color='steelblue', alpha=0.8, 
                          edgecolor=".2", dodge=True, ax=ax[0])
    for p in ax[0].patches:
        width = p.get_width()
        ax[0].text(width, p.get_y()+p.get_height()/2. + 0.2,
                '{:1.2f}'.format(width),
                ha="left")
    
    #League comparison
    league_df = pd.DataFrame.from_dict(league_dict, orient='index').reset_index()
    league_df.columns = ['Penalty', 'Relative to League']
    #league_df['color'] = league_df['Relative to League'].apply(lambda v: 'g' if v > 0.0 else 'r')
    #print(league_df)
    league_comp = sns.barplot(x=league_df['Relative to League'], y=league_df['Penalty'], edgecolor=".2",
                            ax=ax[1])
    for p in ax[1].patches:
        width = p.get_width()
        ax[1].text(width, p.get_y()+p.get_height()/2. + 0.2,
                '{:1.2f}'.format(width),
                ha="left")
    
    plt.tight_layout()
    return team_vs_team['gameNumber'].nunique()

# %%
loadGamePlays('/api/v1/game/2020020001/feed/live')
# Out:
# ([{'result': {'event': 'Game Scheduled',
#     'eventCode': 'PHI1',
#     'eventTypeId': 'GAME_SCHEDULED',
#     'description': 'Game Scheduled'},
#    'about': {'eventIdx': 0,
#     'eventId': 1,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '00:00',
#     'periodTimeRemaining': '20:00',
#     'dateTime': '2021-01-13T21:42:47Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {}},
#   {'result': {'event': 'Period Ready',
#     'eventCode': 'PHI5',
#     'eventTypeId': 'PERIOD_READY',
#     'description': 'Period Ready'},
#    'about': {'eventIdx': 1,
#     'eventId': 5,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '00:00',
#     'periodTimeRemaining': '20:00',
#     'dateTime': '2021-01-13T22:31:10Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {}},
#   {'result': {'event': 'Period Start',
#     'eventCode': 'PHI51',
#     'eventTypeId': 'PERIOD_START',
#     'description': 'Period Start'},
#    'about': {'eventIdx': 2,
#     'eventId': 51,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '00:00',
#     'periodTimeRemaining': '20:00',
#     'dateTime': '2021-01-13T22:32:26Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {}},
#   {'players': [{'player': {'id': 8471675,
#       'fullName': 'Sidney Crosby',
#       'link': '/api/v1/people/8471675'},
#      'playerType': 'Winner'},
#     {'player': {'id': 8476461,
#       'fullName': 'Sean Couturier',
#       'link': '/api/v1/people/8476461'},
#      'playerType': 'Loser'}],
#    'result': {'event': 'Faceoff',
#     'eventCode': 'PHI52',
#     'eventTypeId': 'FACEOFF',
#     'description': 'Sidney Crosby faceoff won against Sean Couturier'},
#    'about': {'eventIdx': 3,
#     'eventId': 52,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '00:00',
#     'periodTimeRemaining': '20:00',
#     'dateTime': '2021-01-13T22:32:45Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': 0.0, 'y': 0.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8478439,
#       'fullName': 'Travis Konecny',
#       'link': '/api/v1/people/8478439'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8477465,
#       'fullName': 'Tristan Jarry',
#       'link': '/api/v1/people/8477465'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI53',
#     'eventTypeId': 'SHOT',
#     'description': 'Travis Konecny Wrist Shot saved by Tristan Jarry',
#     'secondaryType': 'Wrist Shot'},
#    'about': {'eventIdx': 4,
#     'eventId': 53,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '00:16',
#     'periodTimeRemaining': '19:44',
#     'dateTime': '2021-01-13T22:33:00Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': -74.0, 'y': 29.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8478500,
#       'fullName': 'Ivan Provorov',
#       'link': '/api/v1/people/8478500'},
#      'playerType': 'PlayerID'}],
#    'result': {'event': 'Takeaway',
#     'eventCode': 'PHI8',
#     'eventTypeId': 'TAKEAWAY',
#     'description': 'Takeaway by Ivan Provorov'},
#    'about': {'eventIdx': 5,
#     'eventId': 8,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '00:23',
#     'periodTimeRemaining': '19:37',
#     'dateTime': '2021-01-13T22:33:07Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': -39.0, 'y': -36.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8475208,
#       'fullName': 'Brian Dumoulin',
#       'link': '/api/v1/people/8475208'},
#      'playerType': 'Blocker'},
#     {'player': {'id': 8476461,
#       'fullName': 'Sean Couturier',
#       'link': '/api/v1/people/8476461'},
#      'playerType': 'Shooter'}],
#    'result': {'event': 'Blocked Shot',
#     'eventCode': 'PHI54',
#     'eventTypeId': 'BLOCKED_SHOT',
#     'description': 'Sean Couturier shot blocked shot by Brian Dumoulin'},
#    'about': {'eventIdx': 6,
#     'eventId': 54,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '00:28',
#     'periodTimeRemaining': '19:32',
#     'dateTime': '2021-01-13T22:33:11Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': -58.0, 'y': -7.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8478542,
#       'fullName': 'Evan Rodrigues',
#       'link': '/api/v1/people/8478542'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8479394,
#       'fullName': 'Carter Hart',
#       'link': '/api/v1/people/8479394'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI9',
#     'eventTypeId': 'SHOT',
#     'description': 'Evan Rodrigues Wrist Shot saved by Carter Hart',
#     'secondaryType': 'Wrist Shot'},
#    'about': {'eventIdx': 7,
#     'eventId': 9,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '00:34',
#     'periodTimeRemaining': '19:26',
#     'dateTime': '2021-01-13T22:33:18Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': 49.0, 'y': -25.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8475763,
#       'fullName': 'Kevin Hayes',
#       'link': '/api/v1/people/8475763'},
#      'playerType': 'Hitter'},
#     {'player': {'id': 8478507,
#       'fullName': 'John Marino',
#       'link': '/api/v1/people/8478507'},
#      'playerType': 'Hittee'}],
#    'result': {'event': 'Hit',
#     'eventCode': 'PHI10',
#     'eventTypeId': 'HIT',
#     'description': 'Kevin Hayes hit John Marino'},
#    'about': {'eventIdx': 8,
#     'eventId': 10,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '00:51',
#     'periodTimeRemaining': '19:09',
#     'dateTime': '2021-01-13T22:33:35Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': -96.0, 'y': -24.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8480797,
#       'fullName': 'Joel Farabee',
#       'link': '/api/v1/people/8480797'},
#      'playerType': 'Hitter'},
#     {'player': {'id': 8478507,
#       'fullName': 'John Marino',
#       'link': '/api/v1/people/8478507'},
#      'playerType': 'Hittee'}],
#    'result': {'event': 'Hit',
#     'eventCode': 'PHI11',
#     'eventTypeId': 'HIT',
#     'description': 'Joel Farabee hit John Marino'},
#    'about': {'eventIdx': 9,
#     'eventId': 11,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '01:03',
#     'periodTimeRemaining': '18:57',
#     'dateTime': '2021-01-13T22:33:46Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': -87.0, 'y': -33.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8480797,
#       'fullName': 'Joel Farabee',
#       'link': '/api/v1/people/8480797'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8477465,
#       'fullName': 'Tristan Jarry',
#       'link': '/api/v1/people/8477465'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI55',
#     'eventTypeId': 'SHOT',
#     'description': 'Joel Farabee Backhand saved by Tristan Jarry',
#     'secondaryType': 'Backhand'},
#    'about': {'eventIdx': 10,
#     'eventId': 55,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '01:05',
#     'periodTimeRemaining': '18:55',
#     'dateTime': '2021-01-13T22:33:49Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': -52.0, 'y': -31.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'result': {'event': 'Stoppage',
#     'eventCode': 'PHI12',
#     'eventTypeId': 'STOP',
#     'description': 'Goalie Stopped'},
#    'about': {'eventIdx': 11,
#     'eventId': 12,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '01:05',
#     'periodTimeRemaining': '18:55',
#     'dateTime': '2021-01-13T22:33:52Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {}},
#   {'players': [{'player': {'id': 8479974,
#       'fullName': 'Nolan Patrick',
#       'link': '/api/v1/people/8479974'},
#      'playerType': 'Winner'},
#     {'player': {'id': 8476873,
#       'fullName': 'Mark Jankowski',
#       'link': '/api/v1/people/8476873'},
#      'playerType': 'Loser'}],
#    'result': {'event': 'Faceoff',
#     'eventCode': 'PHI56',
#     'eventTypeId': 'FACEOFF',
#     'description': 'Nolan Patrick faceoff won against Mark Jankowski'},
#    'about': {'eventIdx': 12,
#     'eventId': 56,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '01:05',
#     'periodTimeRemaining': '18:55',
#     'dateTime': '2021-01-13T22:34:22Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': -69.0, 'y': -22.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8477462,
#       'fullName': 'Robert Hagg',
#       'link': '/api/v1/people/8477462'},
#      'playerType': 'Hitter'},
#     {'player': {'id': 8479293,
#       'fullName': 'Brandon Tanev',
#       'link': '/api/v1/people/8479293'},
#      'playerType': 'Hittee'}],
#    'result': {'event': 'Hit',
#     'eventCode': 'PHI13',
#     'eventTypeId': 'HIT',
#     'description': 'Robert Hagg hit Brandon Tanev'},
#    'about': {'eventIdx': 13,
#     'eventId': 13,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '01:14',
#     'periodTimeRemaining': '18:46',
#     'dateTime': '2021-01-13T22:34:30Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': -75.0, 'y': -30.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'result': {'event': 'Stoppage',
#     'eventCode': 'PHI14',
#     'eventTypeId': 'STOP',
#     'description': 'Icing'},
#    'about': {'eventIdx': 14,
#     'eventId': 14,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '01:17',
#     'periodTimeRemaining': '18:43',
#     'dateTime': '2021-01-13T22:34:37Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {}},
#   {'players': [{'player': {'id': 8474161,
#       'fullName': 'Jakub Voracek',
#       'link': '/api/v1/people/8474161'},
#      'playerType': 'Winner'},
#     {'player': {'id': 8476873,
#       'fullName': 'Mark Jankowski',
#       'link': '/api/v1/people/8476873'},
#      'playerType': 'Loser'}],
#    'result': {'event': 'Faceoff',
#     'eventCode': 'PHI57',
#     'eventTypeId': 'FACEOFF',
#     'description': 'Jakub Voracek faceoff won against Mark Jankowski'},
#    'about': {'eventIdx': 15,
#     'eventId': 57,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '01:17',
#     'periodTimeRemaining': '18:43',
#     'dateTime': '2021-01-13T22:35:04Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': -69.0, 'y': 22.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8477462,
#       'fullName': 'Robert Hagg',
#       'link': '/api/v1/people/8477462'},
#      'playerType': 'Blocker'},
#     {'player': {'id': 8476873,
#       'fullName': 'Mark Jankowski',
#       'link': '/api/v1/people/8476873'},
#      'playerType': 'Shooter'}],
#    'result': {'event': 'Blocked Shot',
#     'eventCode': 'PHI58',
#     'eventTypeId': 'BLOCKED_SHOT',
#     'description': 'Mark Jankowski shot blocked shot by Robert Hagg'},
#    'about': {'eventIdx': 16,
#     'eventId': 58,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '01:29',
#     'periodTimeRemaining': '18:31',
#     'dateTime': '2021-01-13T22:35:16Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': 54.0, 'y': -16.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8477462,
#       'fullName': 'Robert Hagg',
#       'link': '/api/v1/people/8477462'},
#      'playerType': 'Hitter'},
#     {'player': {'id': 8476873,
#       'fullName': 'Mark Jankowski',
#       'link': '/api/v1/people/8476873'},
#      'playerType': 'Hittee'}],
#    'result': {'event': 'Hit',
#     'eventCode': 'PHI15',
#     'eventTypeId': 'HIT',
#     'description': 'Robert Hagg hit Mark Jankowski'},
#    'about': {'eventIdx': 17,
#     'eventId': 15,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '01:31',
#     'periodTimeRemaining': '18:29',
#     'dateTime': '2021-01-13T22:35:18Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': 93.0, 'y': -23.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8479974,
#       'fullName': 'Nolan Patrick',
#       'link': '/api/v1/people/8479974'},
#      'playerType': 'Blocker'},
#     {'player': {'id': 8479293,
#       'fullName': 'Brandon Tanev',
#       'link': '/api/v1/people/8479293'},
#      'playerType': 'Shooter'}],
#    'result': {'event': 'Blocked Shot',
#     'eventCode': 'PHI60',
#     'eventTypeId': 'BLOCKED_SHOT',
#     'description': 'Brandon Tanev shot blocked shot by Nolan Patrick'},
#    'about': {'eventIdx': 18,
#     'eventId': 60,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '01:41',
#     'periodTimeRemaining': '18:19',
#     'dateTime': '2021-01-13T22:35:28Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': 49.0, 'y': -25.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8479293,
#       'fullName': 'Brandon Tanev',
#       'link': '/api/v1/people/8479293'},
#      'playerType': 'Hitter'},
#     {'player': {'id': 8476979,
#       'fullName': 'Erik Gustafsson',
#       'link': '/api/v1/people/8476979'},
#      'playerType': 'Hittee'}],
#    'result': {'event': 'Hit',
#     'eventCode': 'PHI16',
#     'eventTypeId': 'HIT',
#     'description': 'Brandon Tanev hit Erik Gustafsson'},
#    'about': {'eventIdx': 19,
#     'eventId': 16,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '01:50',
#     'periodTimeRemaining': '18:10',
#     'dateTime': '2021-01-13T22:35:37Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': 87.0, 'y': 32.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'result': {'event': 'Stoppage',
#     'eventCode': 'PHI17',
#     'eventTypeId': 'STOP',
#     'description': 'Icing'},
#    'about': {'eventIdx': 20,
#     'eventId': 17,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '02:09',
#     'periodTimeRemaining': '17:51',
#     'dateTime': '2021-01-13T22:35:57Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {}},
#   {'players': [{'player': {'id': 8476872,
#       'fullName': 'Scott Laughton',
#       'link': '/api/v1/people/8476872'},
#      'playerType': 'Winner'},
#     {'player': {'id': 8471675,
#       'fullName': 'Sidney Crosby',
#       'link': '/api/v1/people/8471675'},
#      'playerType': 'Loser'}],
#    'result': {'event': 'Faceoff',
#     'eventCode': 'PHI61',
#     'eventTypeId': 'FACEOFF',
#     'description': 'Scott Laughton faceoff won against Sidney Crosby'},
#    'about': {'eventIdx': 21,
#     'eventId': 61,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '02:09',
#     'periodTimeRemaining': '17:51',
#     'dateTime': '2021-01-13T22:36:19Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': 69.0, 'y': 22.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8478542,
#       'fullName': 'Evan Rodrigues',
#       'link': '/api/v1/people/8478542'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8479394,
#       'fullName': 'Carter Hart',
#       'link': '/api/v1/people/8479394'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI62',
#     'eventTypeId': 'SHOT',
#     'description': 'Evan Rodrigues Snap Shot saved by Carter Hart',
#     'secondaryType': 'Snap Shot'},
#    'about': {'eventIdx': 22,
#     'eventId': 62,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '02:51',
#     'periodTimeRemaining': '17:09',
#     'dateTime': '2021-01-13T22:37:01Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': 43.0, 'y': 39.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'result': {'event': 'Stoppage',
#     'eventCode': 'PHI18',
#     'eventTypeId': 'STOP',
#     'description': 'Goalie Stopped'},
#    'about': {'eventIdx': 23,
#     'eventId': 18,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '02:51',
#     'periodTimeRemaining': '17:09',
#     'dateTime': '2021-01-13T22:37:06Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {}},
#   {'players': [{'player': {'id': 8473512,
#       'fullName': 'Claude Giroux',
#       'link': '/api/v1/people/8473512'},
#      'playerType': 'Winner'},
#     {'player': {'id': 8471215,
#       'fullName': 'Evgeni Malkin',
#       'link': '/api/v1/people/8471215'},
#      'playerType': 'Loser'}],
#    'result': {'event': 'Faceoff',
#     'eventCode': 'PHI63',
#     'eventTypeId': 'FACEOFF',
#     'description': 'Claude Giroux faceoff won against Evgeni Malkin'},
#    'about': {'eventIdx': 24,
#     'eventId': 63,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '02:51',
#     'periodTimeRemaining': '17:09',
#     'dateTime': '2021-01-13T22:37:31Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': 69.0, 'y': 22.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8479026,
#       'fullName': 'Philippe Myers',
#       'link': '/api/v1/people/8479026'},
#      'playerType': 'Shooter'}],
#    'result': {'event': 'Missed Shot',
#     'eventCode': 'PHI64',
#     'eventTypeId': 'MISSED_SHOT',
#     'description': 'Philippe Myers Wide of Net'},
#    'about': {'eventIdx': 25,
#     'eventId': 64,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '03:29',
#     'periodTimeRemaining': '16:31',
#     'dateTime': '2021-01-13T22:38:08Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': -46.0, 'y': 33.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8475208,
#       'fullName': 'Brian Dumoulin',
#       'link': '/api/v1/people/8475208'},
#      'playerType': 'PlayerID'}],
#    'result': {'event': 'Giveaway',
#     'eventCode': 'PHI19',
#     'eventTypeId': 'GIVEAWAY',
#     'description': 'Giveaway by Brian Dumoulin'},
#    'about': {'eventIdx': 26,
#     'eventId': 19,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '03:43',
#     'periodTimeRemaining': '16:17',
#     'dateTime': '2021-01-13T22:38:23Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': -66.0, 'y': 4.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8473512,
#       'fullName': 'Claude Giroux',
#       'link': '/api/v1/people/8473512'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8477465,
#       'fullName': 'Tristan Jarry',
#       'link': '/api/v1/people/8477465'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI65',
#     'eventTypeId': 'SHOT',
#     'description': 'Claude Giroux Slap Shot saved by Tristan Jarry',
#     'secondaryType': 'Slap Shot'},
#    'about': {'eventIdx': 27,
#     'eventId': 65,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '03:44',
#     'periodTimeRemaining': '16:16',
#     'dateTime': '2021-01-13T22:38:24Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': -53.0, 'y': 8.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8479026,
#       'fullName': 'Philippe Myers',
#       'link': '/api/v1/people/8479026'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8477465,
#       'fullName': 'Tristan Jarry',
#       'link': '/api/v1/people/8477465'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI66',
#     'eventTypeId': 'SHOT',
#     'description': 'Philippe Myers Wrist Shot saved by Tristan Jarry',
#     'secondaryType': 'Wrist Shot'},
#    'about': {'eventIdx': 28,
#     'eventId': 66,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '03:46',
#     'periodTimeRemaining': '16:14',
#     'dateTime': '2021-01-13T22:38:26Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': -70.0, 'y': -3.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8475763,
#       'fullName': 'Kevin Hayes',
#       'link': '/api/v1/people/8475763'},
#      'playerType': 'PlayerID'}],
#    'result': {'event': 'Giveaway',
#     'eventCode': 'PHI20',
#     'eventTypeId': 'GIVEAWAY',
#     'description': 'Giveaway by Kevin Hayes'},
#    'about': {'eventIdx': 29,
#     'eventId': 20,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '04:05',
#     'periodTimeRemaining': '15:55',
#     'dateTime': '2021-01-13T22:38:44Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': -47.0, 'y': 35.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8478067,
#       'fullName': 'Oskar Lindblom',
#       'link': '/api/v1/people/8478067'},
#      'playerType': 'Blocker'},
#     {'player': {'id': 8479293,
#       'fullName': 'Brandon Tanev',
#       'link': '/api/v1/people/8479293'},
#      'playerType': 'Shooter'}],
#    'result': {'event': 'Blocked Shot',
#     'eventCode': 'PHI21',
#     'eventTypeId': 'BLOCKED_SHOT',
#     'description': 'Brandon Tanev shot blocked shot by Oskar Lindblom'},
#    'about': {'eventIdx': 31,
#     'eventId': 21,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '04:30',
#     'periodTimeRemaining': '15:30',
#     'dateTime': '2021-01-13T22:39:09Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': 57.0, 'y': 22.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8478043,
#       'fullName': 'Sam Lafferty',
#       'link': '/api/v1/people/8478043'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8479394,
#       'fullName': 'Carter Hart',
#       'link': '/api/v1/people/8479394'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI67',
#     'eventTypeId': 'SHOT',
#     'description': 'Sam Lafferty Wrist Shot saved by Carter Hart',
#     'secondaryType': 'Wrist Shot'},
#    'about': {'eventIdx': 30,
#     'eventId': 67,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '04:30',
#     'periodTimeRemaining': '15:30',
#     'dateTime': '2021-01-13T22:39:09Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': 59.0, 'y': -35.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8478439,
#       'fullName': 'Travis Konecny',
#       'link': '/api/v1/people/8478439'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8477465,
#       'fullName': 'Tristan Jarry',
#       'link': '/api/v1/people/8477465'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI68',
#     'eventTypeId': 'SHOT',
#     'description': 'Travis Konecny Wrist Shot saved by Tristan Jarry',
#     'secondaryType': 'Wrist Shot'},
#    'about': {'eventIdx': 32,
#     'eventId': 68,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '04:39',
#     'periodTimeRemaining': '15:21',
#     'dateTime': '2021-01-13T22:39:18Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': -59.0, 'y': -28.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8479293,
#       'fullName': 'Brandon Tanev',
#       'link': '/api/v1/people/8479293'},
#      'playerType': 'Hitter'},
#     {'player': {'id': 8474037,
#       'fullName': 'James van Riemsdyk',
#       'link': '/api/v1/people/8474037'},
#      'playerType': 'Hittee'}],
#    'result': {'event': 'Hit',
#     'eventCode': 'PHI69',
#     'eventTypeId': 'HIT',
#     'description': 'Brandon Tanev hit James van Riemsdyk'},
#    'about': {'eventIdx': 33,
#     'eventId': 69,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '04:54',
#     'periodTimeRemaining': '15:06',
#     'dateTime': '2021-01-13T22:39:33Z',
#     'goals': {'away': 0, 'home': 0}},
#    'coordinates': {'x': 55.0, 'y': 42.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8476873,
#       'fullName': 'Mark Jankowski',
#       'link': '/api/v1/people/8476873'},
#      'playerType': 'Scorer',
#      'seasonTotal': 1},
#     {'player': {'id': 8479293,
#       'fullName': 'Brandon Tanev',
#       'link': '/api/v1/people/8479293'},
#      'playerType': 'Assist',
#      'seasonTotal': 1},
#     {'player': {'id': 8477955,
#       'fullName': 'Jared McCann',
#       'link': '/api/v1/people/8477955'},
#      'playerType': 'Assist',
#      'seasonTotal': 1},
#     {'player': {'id': 8479394,
#       'fullName': 'Carter Hart',
#       'link': '/api/v1/people/8479394'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Goal',
#     'eventCode': 'PHI70',
#     'eventTypeId': 'GOAL',
#     'description': 'Mark Jankowski (1) Snap Shot, assists: Brandon Tanev (1), Jared McCann (1)',
#     'secondaryType': 'Snap Shot',
#     'strength': {'code': 'EVEN', 'name': 'Even'},
#     'gameWinningGoal': False,
#     'emptyNet': False},
#    'about': {'eventIdx': 35,
#     'eventId': 70,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '05:12',
#     'periodTimeRemaining': '14:48',
#     'dateTime': '2021-01-13T22:39:53Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 81.0, 'y': -5.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'result': {'event': 'Stoppage',
#     'eventCode': 'PHI206',
#     'eventTypeId': 'STOP',
#     'description': 'Goalie Stopped'},
#    'about': {'eventIdx': 34,
#     'eventId': 206,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '05:12',
#     'periodTimeRemaining': '14:48',
#     'dateTime': '2021-01-13T22:39:53Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {}},
#   {'players': [{'player': {'id': 8476872,
#       'fullName': 'Scott Laughton',
#       'link': '/api/v1/people/8476872'},
#      'playerType': 'Winner'},
#     {'player': {'id': 8471675,
#       'fullName': 'Sidney Crosby',
#       'link': '/api/v1/people/8471675'},
#      'playerType': 'Loser'}],
#    'result': {'event': 'Faceoff',
#     'eventCode': 'PHI23',
#     'eventTypeId': 'FACEOFF',
#     'description': 'Scott Laughton faceoff won against Sidney Crosby'},
#    'about': {'eventIdx': 36,
#     'eventId': 23,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '05:12',
#     'periodTimeRemaining': '14:48',
#     'dateTime': '2021-01-13T22:41:13Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 0.0, 'y': 0.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8476875,
#       'fullName': 'Mike Matheson',
#       'link': '/api/v1/people/8476875'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8479394,
#       'fullName': 'Carter Hart',
#       'link': '/api/v1/people/8479394'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI257',
#     'eventTypeId': 'SHOT',
#     'description': 'Mike Matheson Wrist Shot saved by Carter Hart',
#     'secondaryType': 'Wrist Shot'},
#    'about': {'eventIdx': 37,
#     'eventId': 257,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '05:32',
#     'periodTimeRemaining': '14:28',
#     'dateTime': '2021-01-13T22:49:21Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 32.0, 'y': 0.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8476872,
#       'fullName': 'Scott Laughton',
#       'link': '/api/v1/people/8476872'},
#      'playerType': 'PenaltyOn'},
#     {'player': {'id': 8471675,
#       'fullName': 'Sidney Crosby',
#       'link': '/api/v1/people/8471675'},
#      'playerType': 'DrewBy'}],
#    'result': {'event': 'Penalty',
#     'eventCode': 'PHI113',
#     'eventTypeId': 'PENALTY',
#     'description': 'Scott Laughton Holding against Sidney Crosby',
#     'secondaryType': 'Holding',
#     'penaltySeverity': 'Minor',
#     'penaltyMinutes': 2},
#    'about': {'eventIdx': 38,
#     'eventId': 113,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '05:44',
#     'periodTimeRemaining': '14:16',
#     'dateTime': '2021-01-13T22:41:56Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 95.0, 'y': 22.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8471675,
#       'fullName': 'Sidney Crosby',
#       'link': '/api/v1/people/8471675'},
#      'playerType': 'Winner'},
#     {'player': {'id': 8473512,
#       'fullName': 'Claude Giroux',
#       'link': '/api/v1/people/8473512'},
#      'playerType': 'Loser'}],
#    'result': {'event': 'Faceoff',
#     'eventCode': 'PHI71',
#     'eventTypeId': 'FACEOFF',
#     'description': 'Sidney Crosby faceoff won against Claude Giroux'},
#    'about': {'eventIdx': 39,
#     'eventId': 71,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '05:44',
#     'periodTimeRemaining': '14:16',
#     'dateTime': '2021-01-13T22:42:16Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 69.0, 'y': 22.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8478500,
#       'fullName': 'Ivan Provorov',
#       'link': '/api/v1/people/8478500'},
#      'playerType': 'PlayerID'}],
#    'result': {'event': 'Giveaway',
#     'eventCode': 'PHI72',
#     'eventTypeId': 'GIVEAWAY',
#     'description': 'Giveaway by Ivan Provorov'},
#    'about': {'eventIdx': 40,
#     'eventId': 72,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '06:01',
#     'periodTimeRemaining': '13:59',
#     'dateTime': '2021-01-13T22:42:32Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 96.0, 'y': 9.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'result': {'event': 'Stoppage',
#     'eventCode': 'PHI25',
#     'eventTypeId': 'STOP',
#     'description': 'Puck in Crowd'},
#    'about': {'eventIdx': 41,
#     'eventId': 25,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '06:15',
#     'periodTimeRemaining': '13:45',
#     'dateTime': '2021-01-13T22:43:10Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {}},
#   {'players': [{'player': {'id': 8471675,
#       'fullName': 'Sidney Crosby',
#       'link': '/api/v1/people/8471675'},
#      'playerType': 'Winner'},
#     {'player': {'id': 8475763,
#       'fullName': 'Kevin Hayes',
#       'link': '/api/v1/people/8475763'},
#      'playerType': 'Loser'}],
#    'result': {'event': 'Faceoff',
#     'eventCode': 'PHI73',
#     'eventTypeId': 'FACEOFF',
#     'description': 'Sidney Crosby faceoff won against Kevin Hayes'},
#    'about': {'eventIdx': 42,
#     'eventId': 73,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '06:15',
#     'periodTimeRemaining': '13:45',
#     'dateTime': '2021-01-13T22:43:20Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': -69.0, 'y': 22.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8475810,
#       'fullName': 'Bryan Rust',
#       'link': '/api/v1/people/8475810'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8479394,
#       'fullName': 'Carter Hart',
#       'link': '/api/v1/people/8479394'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI74',
#     'eventTypeId': 'SHOT',
#     'description': 'Bryan Rust Wrist Shot saved by Carter Hart',
#     'secondaryType': 'Wrist Shot'},
#    'about': {'eventIdx': 43,
#     'eventId': 74,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '06:38',
#     'periodTimeRemaining': '13:22',
#     'dateTime': '2021-01-13T22:43:43Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 46.0, 'y': -21.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8475722,
#       'fullName': 'Jason Zucker',
#       'link': '/api/v1/people/8475722'},
#      'playerType': 'Hitter'},
#     {'player': {'id': 8479026,
#       'fullName': 'Philippe Myers',
#       'link': '/api/v1/people/8479026'},
#      'playerType': 'Hittee'}],
#    'result': {'event': 'Hit',
#     'eventCode': 'PHI26',
#     'eventTypeId': 'HIT',
#     'description': 'Jason Zucker hit Philippe Myers'},
#    'about': {'eventIdx': 44,
#     'eventId': 26,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '07:17',
#     'periodTimeRemaining': '12:43',
#     'dateTime': '2021-01-13T22:44:22Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 95.0, 'y': -8.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8477955,
#       'fullName': 'Jared McCann',
#       'link': '/api/v1/people/8477955'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8479394,
#       'fullName': 'Carter Hart',
#       'link': '/api/v1/people/8479394'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI75',
#     'eventTypeId': 'SHOT',
#     'description': 'Jared McCann Backhand saved by Carter Hart',
#     'secondaryType': 'Backhand'},
#    'about': {'eventIdx': 45,
#     'eventId': 75,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '07:20',
#     'periodTimeRemaining': '12:40',
#     'dateTime': '2021-01-13T22:44:24Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 85.0, 'y': 15.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'result': {'event': 'Stoppage',
#     'eventCode': 'PHI27',
#     'eventTypeId': 'STOP',
#     'description': 'Goalie Stopped'},
#    'about': {'eventIdx': 46,
#     'eventId': 27,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '07:20',
#     'periodTimeRemaining': '12:40',
#     'dateTime': '2021-01-13T22:44:31Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {}},
#   {'players': [{'player': {'id': 8471675,
#       'fullName': 'Sidney Crosby',
#       'link': '/api/v1/people/8471675'},
#      'playerType': 'Winner'},
#     {'player': {'id': 8473512,
#       'fullName': 'Claude Giroux',
#       'link': '/api/v1/people/8473512'},
#      'playerType': 'Loser'}],
#    'result': {'event': 'Faceoff',
#     'eventCode': 'PHI76',
#     'eventTypeId': 'FACEOFF',
#     'description': 'Sidney Crosby faceoff won against Claude Giroux'},
#    'about': {'eventIdx': 47,
#     'eventId': 76,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '07:20',
#     'periodTimeRemaining': '12:40',
#     'dateTime': '2021-01-13T22:44:50Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 69.0, 'y': 22.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8476979,
#       'fullName': 'Erik Gustafsson',
#       'link': '/api/v1/people/8476979'},
#      'playerType': 'PlayerID'}],
#    'result': {'event': 'Giveaway',
#     'eventCode': 'PHI28',
#     'eventTypeId': 'GIVEAWAY',
#     'description': 'Giveaway by Erik Gustafsson'},
#    'about': {'eventIdx': 48,
#     'eventId': 28,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '08:11',
#     'periodTimeRemaining': '11:49',
#     'dateTime': '2021-01-13T22:45:41Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 70.0, 'y': 37.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8477462,
#       'fullName': 'Robert Hagg',
#       'link': '/api/v1/people/8477462'},
#      'playerType': 'Blocker'},
#     {'player': {'id': 8474098,
#       'fullName': 'Colton Sceviour',
#       'link': '/api/v1/people/8474098'},
#      'playerType': 'Shooter'}],
#    'result': {'event': 'Blocked Shot',
#     'eventCode': 'PHI77',
#     'eventTypeId': 'BLOCKED_SHOT',
#     'description': 'Colton Sceviour shot blocked shot by Robert Hagg'},
#    'about': {'eventIdx': 49,
#     'eventId': 77,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '08:15',
#     'periodTimeRemaining': '11:45',
#     'dateTime': '2021-01-13T22:45:45Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 58.0, 'y': -9.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8476979,
#       'fullName': 'Erik Gustafsson',
#       'link': '/api/v1/people/8476979'},
#      'playerType': 'Hitter'},
#     {'player': {'id': 8474098,
#       'fullName': 'Colton Sceviour',
#       'link': '/api/v1/people/8474098'},
#      'playerType': 'Hittee'}],
#    'result': {'event': 'Hit',
#     'eventCode': 'PHI29',
#     'eventTypeId': 'HIT',
#     'description': 'Erik Gustafsson hit Colton Sceviour'},
#    'about': {'eventIdx': 50,
#     'eventId': 29,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '08:25',
#     'periodTimeRemaining': '11:35',
#     'dateTime': '2021-01-13T22:45:55Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 96.0, 'y': 22.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8479293,
#       'fullName': 'Brandon Tanev',
#       'link': '/api/v1/people/8479293'},
#      'playerType': 'Hitter'},
#     {'player': {'id': 8480797,
#       'fullName': 'Joel Farabee',
#       'link': '/api/v1/people/8480797'},
#      'playerType': 'Hittee'}],
#    'result': {'event': 'Hit',
#     'eventCode': 'PHI30',
#     'eventTypeId': 'HIT',
#     'description': 'Brandon Tanev hit Joel Farabee'},
#    'about': {'eventIdx': 51,
#     'eventId': 30,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '09:03',
#     'periodTimeRemaining': '10:57',
#     'dateTime': '2021-01-13T22:46:33Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 51.0, 'y': 40.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8477955,
#       'fullName': 'Jared McCann',
#       'link': '/api/v1/people/8477955'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8479394,
#       'fullName': 'Carter Hart',
#       'link': '/api/v1/people/8479394'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI78',
#     'eventTypeId': 'SHOT',
#     'description': 'Jared McCann Snap Shot saved by Carter Hart',
#     'secondaryType': 'Snap Shot'},
#    'about': {'eventIdx': 52,
#     'eventId': 78,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '09:08',
#     'periodTimeRemaining': '10:52',
#     'dateTime': '2021-01-13T22:46:38Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 52.0, 'y': -20.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'result': {'event': 'Stoppage',
#     'eventCode': 'PHI31',
#     'eventTypeId': 'STOP',
#     'description': 'Net Dislodged Defensive Skater'},
#    'about': {'eventIdx': 53,
#     'eventId': 31,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '09:13',
#     'periodTimeRemaining': '10:47',
#     'dateTime': '2021-01-13T22:46:45Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {}},
#   {'players': [{'player': {'id': 8476461,
#       'fullName': 'Sean Couturier',
#       'link': '/api/v1/people/8476461'},
#      'playerType': 'Winner'},
#     {'player': {'id': 8476873,
#       'fullName': 'Mark Jankowski',
#       'link': '/api/v1/people/8476873'},
#      'playerType': 'Loser'}],
#    'result': {'event': 'Faceoff',
#     'eventCode': 'PHI79',
#     'eventTypeId': 'FACEOFF',
#     'description': 'Sean Couturier faceoff won against Mark Jankowski'},
#    'about': {'eventIdx': 54,
#     'eventId': 79,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '09:13',
#     'periodTimeRemaining': '10:47',
#     'dateTime': '2021-01-13T22:49:10Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': -69.0, 'y': 22.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8479293,
#       'fullName': 'Brandon Tanev',
#       'link': '/api/v1/people/8479293'},
#      'playerType': 'Shooter'}],
#    'result': {'event': 'Missed Shot',
#     'eventCode': 'PHI80',
#     'eventTypeId': 'MISSED_SHOT',
#     'description': 'Brandon Tanev Wide of Net'},
#    'about': {'eventIdx': 55,
#     'eventId': 80,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '09:34',
#     'periodTimeRemaining': '10:26',
#     'dateTime': '2021-01-13T22:49:30Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 69.0, 'y': -9.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8477465,
#       'fullName': 'Tristan Jarry',
#       'link': '/api/v1/people/8477465'},
#      'playerType': 'PlayerID'}],
#    'result': {'event': 'Giveaway',
#     'eventCode': 'PHI32',
#     'eventTypeId': 'GIVEAWAY',
#     'description': 'Giveaway by Tristan Jarry'},
#    'about': {'eventIdx': 56,
#     'eventId': 32,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '10:00',
#     'periodTimeRemaining': '10:00',
#     'dateTime': '2021-01-13T22:49:55Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': -97.0, 'y': -6.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8471215,
#       'fullName': 'Evgeni Malkin',
#       'link': '/api/v1/people/8471215'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8479394,
#       'fullName': 'Carter Hart',
#       'link': '/api/v1/people/8479394'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI81',
#     'eventTypeId': 'SHOT',
#     'description': 'Evgeni Malkin Wrist Shot saved by Carter Hart',
#     'secondaryType': 'Wrist Shot'},
#    'about': {'eventIdx': 57,
#     'eventId': 81,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '10:33',
#     'periodTimeRemaining': '09:27',
#     'dateTime': '2021-01-13T22:50:29Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 63.0, 'y': -37.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'result': {'event': 'Stoppage',
#     'eventCode': 'PHI33',
#     'eventTypeId': 'STOP',
#     'description': 'Puck in Crowd'},
#    'about': {'eventIdx': 58,
#     'eventId': 33,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '11:21',
#     'periodTimeRemaining': '08:39',
#     'dateTime': '2021-01-13T22:51:19Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {}},
#   {'players': [{'player': {'id': 8473512,
#       'fullName': 'Claude Giroux',
#       'link': '/api/v1/people/8473512'},
#      'playerType': 'Winner'},
#     {'player': {'id': 8476927,
#       'fullName': 'Teddy Blueger',
#       'link': '/api/v1/people/8476927'},
#      'playerType': 'Loser'}],
#    'result': {'event': 'Faceoff',
#     'eventCode': 'PHI82',
#     'eventTypeId': 'FACEOFF',
#     'description': 'Claude Giroux faceoff won against Teddy Blueger'},
#    'about': {'eventIdx': 59,
#     'eventId': 82,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '11:21',
#     'periodTimeRemaining': '08:39',
#     'dateTime': '2021-01-13T22:53:36Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': 69.0, 'y': 22.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8476979,
#       'fullName': 'Erik Gustafsson',
#       'link': '/api/v1/people/8476979'},
#      'playerType': 'Shooter'}],
#    'result': {'event': 'Missed Shot',
#     'eventCode': 'PHI83',
#     'eventTypeId': 'MISSED_SHOT',
#     'description': 'Erik Gustafsson Wide of Net'},
#    'about': {'eventIdx': 60,
#     'eventId': 83,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '11:35',
#     'periodTimeRemaining': '08:25',
#     'dateTime': '2021-01-13T22:53:50Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': -40.0, 'y': 34.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8477462,
#       'fullName': 'Robert Hagg',
#       'link': '/api/v1/people/8477462'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8477465,
#       'fullName': 'Tristan Jarry',
#       'link': '/api/v1/people/8477465'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI34',
#     'eventTypeId': 'SHOT',
#     'description': 'Robert Hagg Snap Shot saved by Tristan Jarry',
#     'secondaryType': 'Snap Shot'},
#    'about': {'eventIdx': 61,
#     'eventId': 34,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '11:39',
#     'periodTimeRemaining': '08:21',
#     'dateTime': '2021-01-13T22:53:54Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': -35.0, 'y': -34.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8474098,
#       'fullName': 'Colton Sceviour',
#       'link': '/api/v1/people/8474098'},
#      'playerType': 'PlayerID'}],
#    'result': {'event': 'Giveaway',
#     'eventCode': 'PHI35',
#     'eventTypeId': 'GIVEAWAY',
#     'description': 'Giveaway by Colton Sceviour'},
#    'about': {'eventIdx': 62,
#     'eventId': 35,
#     'period': 1,
#     'periodType': 'REGULAR',
#     'ordinalNum': '1st',
#     'periodTime': '11:45',
#     'periodTimeRemaining': '08:15',
#     'dateTime': '2021-01-13T22:54:00Z',
#     'goals': {'away': 1, 'home': 0}},
#    'coordinates': {'x': -80.0, 'y': -33.0},
# ...
#      'playerType': 'Winner'},
#     {'player': {'id': 8473512,
#       'fullName': 'Claude Giroux',
#       'link': '/api/v1/people/8473512'},
#      'playerType': 'Loser'}],
#    'result': {'event': 'Faceoff',
#     'eventCode': 'PHI533',
#     'eventTypeId': 'FACEOFF',
#     'description': 'Evgeni Malkin faceoff won against Claude Giroux'},
#    'about': {'eventIdx': 270,
#     'eventId': 533,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '17:17',
#     'periodTimeRemaining': '02:43',
#     'dateTime': '2021-01-14T00:50:23Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': 69.0, 'y': 22.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8479026,
#       'fullName': 'Philippe Myers',
#       'link': '/api/v1/people/8479026'},
#      'playerType': 'Hitter'},
#     {'player': {'id': 8471215,
#       'fullName': 'Evgeni Malkin',
#       'link': '/api/v1/people/8471215'},
#      'playerType': 'Hittee'}],
#    'result': {'event': 'Hit',
#     'eventCode': 'PHI652',
#     'eventTypeId': 'HIT',
#     'description': 'Philippe Myers hit Evgeni Malkin'},
#    'about': {'eventIdx': 271,
#     'eventId': 652,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '17:25',
#     'periodTimeRemaining': '02:35',
#     'dateTime': '2021-01-14T00:50:30Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': 99.0, 'y': -1.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8475722,
#       'fullName': 'Jason Zucker',
#       'link': '/api/v1/people/8475722'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8479394,
#       'fullName': 'Carter Hart',
#       'link': '/api/v1/people/8479394'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI534',
#     'eventTypeId': 'SHOT',
#     'description': 'Jason Zucker Backhand saved by Carter Hart',
#     'secondaryType': 'Backhand'},
#    'about': {'eventIdx': 272,
#     'eventId': 534,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '17:37',
#     'periodTimeRemaining': '02:23',
#     'dateTime': '2021-01-14T00:50:43Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': 70.0, 'y': -14.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8471215,
#       'fullName': 'Evgeni Malkin',
#       'link': '/api/v1/people/8471215'},
#      'playerType': 'PlayerID'}],
#    'result': {'event': 'Takeaway',
#     'eventCode': 'PHI653',
#     'eventTypeId': 'TAKEAWAY',
#     'description': 'Takeaway by Evgeni Malkin'},
#    'about': {'eventIdx': 273,
#     'eventId': 653,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '17:45',
#     'periodTimeRemaining': '02:15',
#     'dateTime': '2021-01-14T00:50:51Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': 60.0, 'y': -13.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8471215,
#       'fullName': 'Evgeni Malkin',
#       'link': '/api/v1/people/8471215'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8479394,
#       'fullName': 'Carter Hart',
#       'link': '/api/v1/people/8479394'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI535',
#     'eventTypeId': 'SHOT',
#     'description': 'Evgeni Malkin Wrist Shot saved by Carter Hart',
#     'secondaryType': 'Wrist Shot'},
#    'about': {'eventIdx': 274,
#     'eventId': 535,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '17:49',
#     'periodTimeRemaining': '02:11',
#     'dateTime': '2021-01-14T00:50:55Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': 63.0, 'y': 19.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'result': {'event': 'Stoppage',
#     'eventCode': 'PHI654',
#     'eventTypeId': 'STOP',
#     'description': 'Goalie Stopped'},
#    'about': {'eventIdx': 275,
#     'eventId': 654,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '17:49',
#     'periodTimeRemaining': '02:11',
#     'dateTime': '2021-01-14T00:51:05Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {}},
#   {'players': [{'player': {'id': 8479974,
#       'fullName': 'Nolan Patrick',
#       'link': '/api/v1/people/8479974'},
#      'playerType': 'Winner'},
#     {'player': {'id': 8476873,
#       'fullName': 'Mark Jankowski',
#       'link': '/api/v1/people/8476873'},
#      'playerType': 'Loser'}],
#    'result': {'event': 'Faceoff',
#     'eventCode': 'PHI536',
#     'eventTypeId': 'FACEOFF',
#     'description': 'Nolan Patrick faceoff won against Mark Jankowski'},
#    'about': {'eventIdx': 276,
#     'eventId': 536,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '17:49',
#     'periodTimeRemaining': '02:11',
#     'dateTime': '2021-01-14T00:51:32Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': 69.0, 'y': 22.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8479293,
#       'fullName': 'Brandon Tanev',
#       'link': '/api/v1/people/8479293'},
#      'playerType': 'PlayerID'}],
#    'result': {'event': 'Takeaway',
#     'eventCode': 'PHI655',
#     'eventTypeId': 'TAKEAWAY',
#     'description': 'Takeaway by Brandon Tanev'},
#    'about': {'eventIdx': 277,
#     'eventId': 655,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '18:11',
#     'periodTimeRemaining': '01:49',
#     'dateTime': '2021-01-14T00:51:52Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': -26.0, 'y': -18.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8477955,
#       'fullName': 'Jared McCann',
#       'link': '/api/v1/people/8477955'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8479394,
#       'fullName': 'Carter Hart',
#       'link': '/api/v1/people/8479394'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI537',
#     'eventTypeId': 'SHOT',
#     'description': 'Jared McCann Wrist Shot saved by Carter Hart',
#     'secondaryType': 'Wrist Shot'},
#    'about': {'eventIdx': 278,
#     'eventId': 537,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '18:20',
#     'periodTimeRemaining': '01:40',
#     'dateTime': '2021-01-14T00:52:01Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': 49.0, 'y': 37.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8476872,
#       'fullName': 'Scott Laughton',
#       'link': '/api/v1/people/8476872'},
#      'playerType': 'Hitter'},
#     {'player': {'id': 8477969,
#       'fullName': 'Marcus Pettersson',
#       'link': '/api/v1/people/8477969'},
#      'playerType': 'Hittee'}],
#    'result': {'event': 'Hit',
#     'eventCode': 'PHI656',
#     'eventTypeId': 'HIT',
#     'description': 'Scott Laughton hit Marcus Pettersson'},
#    'about': {'eventIdx': 279,
#     'eventId': 656,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '18:35',
#     'periodTimeRemaining': '01:25',
#     'dateTime': '2021-01-14T00:52:17Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': -95.0, 'y': -11.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8474098,
#       'fullName': 'Colton Sceviour',
#       'link': '/api/v1/people/8474098'},
#      'playerType': 'Blocker'},
#     {'player': {'id': 8476872,
#       'fullName': 'Scott Laughton',
#       'link': '/api/v1/people/8476872'},
#      'playerType': 'Shooter'}],
#    'result': {'event': 'Blocked Shot',
#     'eventCode': 'PHI538',
#     'eventTypeId': 'BLOCKED_SHOT',
#     'description': 'Scott Laughton shot blocked shot by Colton Sceviour'},
#    'about': {'eventIdx': 280,
#     'eventId': 538,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '18:45',
#     'periodTimeRemaining': '01:15',
#     'dateTime': '2021-01-14T00:52:27Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': -74.0, 'y': -6.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8477979,
#       'fullName': 'Nicolas Aube-Kubel',
#       'link': '/api/v1/people/8477979'},
#      'playerType': 'Hitter'},
#     {'player': {'id': 8478043,
#       'fullName': 'Sam Lafferty',
#       'link': '/api/v1/people/8478043'},
#      'playerType': 'Hittee'}],
#    'result': {'event': 'Hit',
#     'eventCode': 'PHI657',
#     'eventTypeId': 'HIT',
#     'description': 'Nicolas Aube-Kubel hit Sam Lafferty'},
#    'about': {'eventIdx': 281,
#     'eventId': 657,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '18:56',
#     'periodTimeRemaining': '01:04',
#     'dateTime': '2021-01-14T00:52:37Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': -60.0, 'y': -35.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8477969,
#       'fullName': 'Marcus Pettersson',
#       'link': '/api/v1/people/8477969'},
#      'playerType': 'Shooter'},
#     {'player': {'id': 8479394,
#       'fullName': 'Carter Hart',
#       'link': '/api/v1/people/8479394'},
#      'playerType': 'Goalie'}],
#    'result': {'event': 'Shot',
#     'eventCode': 'PHI541',
#     'eventTypeId': 'SHOT',
#     'description': 'Marcus Pettersson Backhand saved by Carter Hart',
#     'secondaryType': 'Backhand'},
#    'about': {'eventIdx': 282,
#     'eventId': 541,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '18:59',
#     'periodTimeRemaining': '01:01',
#     'dateTime': '2021-01-14T00:52:41Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': 76.0, 'y': -1.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8477979,
#       'fullName': 'Nicolas Aube-Kubel',
#       'link': '/api/v1/people/8477979'},
#      'playerType': 'Shooter'}],
#    'result': {'event': 'Missed Shot',
#     'eventCode': 'PHI539',
#     'eventTypeId': 'MISSED_SHOT',
#     'description': 'Nicolas Aube-Kubel Wide of Net'},
#    'about': {'eventIdx': 283,
#     'eventId': 539,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '19:07',
#     'periodTimeRemaining': '00:53',
#     'dateTime': '2021-01-14T00:52:49Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': -65.0, 'y': 22.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'players': [{'player': {'id': 8474098,
#       'fullName': 'Colton Sceviour',
#       'link': '/api/v1/people/8474098'},
#      'playerType': 'Hitter'},
#     {'player': {'id': 8477462,
#       'fullName': 'Robert Hagg',
#       'link': '/api/v1/people/8477462'},
#      'playerType': 'Hittee'}],
#    'result': {'event': 'Hit',
#     'eventCode': 'PHI658',
#     'eventTypeId': 'HIT',
#     'description': 'Colton Sceviour hit Robert Hagg'},
#    'about': {'eventIdx': 284,
#     'eventId': 658,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '19:10',
#     'periodTimeRemaining': '00:50',
#     'dateTime': '2021-01-14T00:52:52Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': -66.0, 'y': -36.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8477955,
#       'fullName': 'Jared McCann',
#       'link': '/api/v1/people/8477955'},
#      'playerType': 'PlayerID'}],
#    'result': {'event': 'Takeaway',
#     'eventCode': 'PHI659',
#     'eventTypeId': 'TAKEAWAY',
#     'description': 'Takeaway by Jared McCann'},
#    'about': {'eventIdx': 285,
#     'eventId': 659,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '19:30',
#     'periodTimeRemaining': '00:30',
#     'dateTime': '2021-01-14T00:53:12Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': 60.0, 'y': -36.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8476875,
#       'fullName': 'Mike Matheson',
#       'link': '/api/v1/people/8476875'},
#      'playerType': 'Shooter'}],
#    'result': {'event': 'Missed Shot',
#     'eventCode': 'PHI540',
#     'eventTypeId': 'MISSED_SHOT',
#     'description': 'Mike Matheson Wide of Net'},
#    'about': {'eventIdx': 286,
#     'eventId': 540,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '19:35',
#     'periodTimeRemaining': '00:25',
#     'dateTime': '2021-01-14T00:53:17Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': 44.0, 'y': 6.0},
#    'team': {'id': 5,
#     'name': 'Pittsburgh Penguins',
#     'link': '/api/v1/teams/5',
#     'triCode': 'PIT'}},
#   {'players': [{'player': {'id': 8474037,
#       'fullName': 'James van Riemsdyk',
#       'link': '/api/v1/people/8474037'},
#      'playerType': 'Blocker'},
#     {'player': {'id': 8478507,
#       'fullName': 'John Marino',
#       'link': '/api/v1/people/8478507'},
#      'playerType': 'Shooter'}],
#    'result': {'event': 'Blocked Shot',
#     'eventCode': 'PHI660',
#     'eventTypeId': 'BLOCKED_SHOT',
#     'description': 'John Marino shot blocked shot by James van Riemsdyk'},
#    'about': {'eventIdx': 287,
#     'eventId': 660,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '19:40',
#     'periodTimeRemaining': '00:20',
#     'dateTime': '2021-01-14T00:53:22Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {'x': 63.0, 'y': 5.0},
#    'team': {'id': 4,
#     'name': 'Philadelphia Flyers',
#     'link': '/api/v1/teams/4',
#     'triCode': 'PHI'}},
#   {'result': {'event': 'Period End',
#     'eventCode': 'PHI661',
#     'eventTypeId': 'PERIOD_END',
#     'description': 'End of 3rd Period'},
#    'about': {'eventIdx': 288,
#     'eventId': 661,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '20:00',
#     'periodTimeRemaining': '00:00',
#     'dateTime': '2021-01-14T00:53:42Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {}},
#   {'result': {'event': 'Period Official',
#     'eventCode': 'PHI664',
#     'eventTypeId': 'PERIOD_OFFICIAL',
#     'description': 'Period Official'},
#    'about': {'eventIdx': 289,
#     'eventId': 664,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '20:00',
#     'periodTimeRemaining': '00:00',
#     'dateTime': '2021-01-14T00:53:50Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {}},
#   {'result': {'event': 'Game End',
#     'eventCode': 'PHI665',
#     'eventTypeId': 'GAME_END',
#     'description': 'Game End'},
#    'about': {'eventIdx': 290,
#     'eventId': 665,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '20:00',
#     'periodTimeRemaining': '00:00',
#     'dateTime': '2021-01-14T00:53:50Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {}},
#   {'result': {'event': 'Game Official',
#     'eventCode': 'PHI992',
#     'eventTypeId': 'GAME_OFFICIAL',
#     'description': 'Game Official'},
#    'about': {'eventIdx': 291,
#     'eventId': 992,
#     'period': 3,
#     'periodType': 'REGULAR',
#     'ordinalNum': '3rd',
#     'periodTime': '20:00',
#     'periodTimeRemaining': '00:00',
#     'dateTime': '2021-01-16T18:23:46Z',
#     'goals': {'away': 3, 'home': 6}},
#    'coordinates': {}}],
#  'PHI',
#  'PIT')
